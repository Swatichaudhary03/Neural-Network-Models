# %% [markdown]
# Train a fully connected neural network (multilayer perceptron) to classify handwritten digits using the MNIST dataset by building a simple neural network, experimenting with activation functions, and tuning hyperparameters.

# %% [markdown]
# 1. Objective

# %% [markdown]
# Train a fully connected neural network (MLP) on the MNIST dataset for digit classification (0–9).
# You will:
#
# Load the MNIST dataset
#
# Build an MLP based neural network architecture
#
# Try different activation functions
#
# Tune key hyperparameters
#
# Train and evaluate the model

# %% [markdown]
# 2. Import Required Libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# 3. Load & Preprocess MNIST Dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values (0-255 → 0-1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# 4. Build a Simple MLP Model

# %%
Flatten layer (28×28 → 784)

Dense(128) – hidden layer

Activation: Relu

Dense(10) – output layer (softmax for probability)

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 5. Train the Model

# %%
history = model.fit(x_train, y_train,
                    validation_split=0.1,
                    epochs=10,
                    batch_size=32)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8686 - loss: 0.4675 - val_accuracy: 0.9627 - val_loss: 0.1332
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9629 - loss: 0.1293 - val_accuracy: 0.9710 - val_loss: 0.0962
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9760 - loss: 0.0798 - val_accuracy: 0.9725 - val_loss: 0.0936
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9823 - loss: 0.0603 - val_accuracy: 0.9745 - val_loss: 0.0853
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9865 - loss: 0.0451 - val_accuracy: 0.9747 - val_loss: 0.0862
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9888 - loss: 0.0363 - val_accuracy: 0.9752 - val_loss: 0.0838
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9919 - loss: 0.0290 - val_accuracy: 0.9773 - val_loss: 0.0805
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9934 - loss: 0.0227 - val_accuracy: 0.9747 - val_loss: 0.0979
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9946 - loss: 0.0184 - val_accuracy: 0.9795 - val_loss: 0.0838
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9965 - loss: 0.0139 - val_accuracy: 0.9805 - val_loss: 0.0806

# %% [markdown]
# 6. Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9770 - loss: 0.0974
# Test Accuracy: 0.9793000221252441

# %% [markdown]
# 7. Experiment With Different Activation Functions

# %%
from tensorflow.keras.layers import LeakyReLU

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256),
    LeakyReLU(alpha=0.1),
    Dense(128, activation='tanh'),
    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# 8. Hyperparameter

# %%
1. Number of Hidden Layers

# %%
Dense(256, activation='relu')
Dense(128, activation='relu')
Dense(64, activation='relu')
# Out:
# <Dense name=dense_7, built=False>

# %%
2. Change Optimizer

# %%
optimizer='sgd'     # slower but stable
optimizer='adam'    # best default choice
optimizer='rmsprop'

# %%
✔ 3. Change Learning Rate

# %%
from tensorflow.keras.optimizers import Adam
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
Add Dropout

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# Final Improved Model (Recommended)model = Sequential([
#     Flatten(input_shape=(28, 28)),
#     Dense(256, activation='relu'),
#     Dropout(0.3),
#     Dense(128, activation='relu'),
#     Dropout(0.2),
#     Dense(10, activation='softmax')
# ])
#
# model.compile(optimizer='adam',
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])
#
# model.fit(x_train, y_train,
#           validation_split=0.1,
#           epochs=15,
#           batch_size=64)
